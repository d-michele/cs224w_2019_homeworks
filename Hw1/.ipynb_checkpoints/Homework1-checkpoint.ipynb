# %%
import numpy as np
from math import ceil
import hw1_q1_starter
import snap
# from hw1_q1_starter import *
import networkx as nx
np.random.seed(1234)

# %%
from importlib import reload
reload(hw1_q1_starter)
# Out:
# Clustering Coefficient for Erdos Renyi Network: 0.001192
# Clustering Coefficient for Small World Network: 0.284738
# Clustering Coefficient for Collaboration Network: 0.529636
# <module 'hw1_q1_starter' from '/run/media/michele/DATI/projects/CS224W/Hw1/hw1_q1_starter.py'>

# %%
G = snap.TUNGraph.Load(snap.TFIn('hw1-q2.graph'))
G.GetEdges()
# Out:
# 2742

# %%
import hw1_q2_starter as hq2
reload(hq2)
GCollab = hq2.load_netscience_graph()

# %%
hq2.topk_most_similar(9, GCollab)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-155-4695fbb36f1f> in <module>
# ----> 1 hq2.topk_most_similar(9, GCollab)
#
# /run/media/michele/DATI/projects/CS224W/Hw1/hw1_q2_starter.py in topk_most_similar(node_id, graph, k)
#      67         if id == node_id:
#      68             continue
# ---> 69         u = get_basic_features(node_id, graph)
#      70         v = get_basic_features(id, graph)
#      71         sim = cosine_similarity(u,v)
#
# /run/media/michele/DATI/projects/CS224W/Hw1/hw1_q2_starter.py in get_basic_features(node_id, graph)
#      10
#      11     k = graph.GetNI(node_id).GetDeg()
# ---> 12     num_intra_edges, num_inter_edges = get_egonet_inter_intra_num_edges(node_id, graph)
#      13     # num_intra_edges = egonet.GetEdges()
#      14
#
# ...

# %%
a = np.array(5.9)

# %%
a[()]
# Out:
# 5.9
